# %%
# Importing pandas
import pandas as pd

# %%
# Setting the CSV to a DataFrame
df = pd.read_csv("adult.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# ## **Data Inspection**
#
# Data inspection is the initial review of a dataset to find missing values, incorrect data types, and gather basic statistics, providing insights into its quality and structure.

# %%
# Identify Missing Values

# Per cell, True if empty, False if not empty
df.isnull()

# Checking every column for True values
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# Identify Specific Characters/Values
(df == '?').sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
# Identify Data Types
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
# Initial Analysis Before Cleaning
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# ## **Cleaning Data**
#
# Cleaning data involves eliminating or rectifying inaccuracies, inconsistencies, and missing values within your dataset, utilizing techniques such as handling missing values via deletion or imputation, rectifying data types, and detecting and eliminating duplicate entries, ultimately resulting in more precise and dependable analysis.

# %%
# Replacing null representation values with null

# replace(character/value to replace, what to replace it with, inplace/save)
df.replace('?', pd.NA, inplace=True)

# Checking every column for True values
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18          <NA>  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married               <NA>    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
# Replace null values with a placeholder value
df['occupation'] = df['occupation'].fillna("Unemployed")
df['occupation']
# Out:
# 0        Machine-op-inspct
# 1          Farming-fishing
# 2          Protective-serv
# 3        Machine-op-inspct
# 4               Unemployed
#                ...
# 48837         Tech-support
# 48838    Machine-op-inspct
# 48839         Adm-clerical
# 48840         Adm-clerical
# 48841      Exec-managerial
# Name: occupation, Length: 48842, dtype: object

# %%
# Drop rows with null values
df.dropna(inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [45232 rows x 15 columns]

# %% [markdown]
# ## Trimming and Cleaning Text Data

# %%
# Remove beginning and ending whitespaces
df['workclass'] = df['workclass'].str.strip()
df['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45232, dtype: object

# %%
# Replace text with other text
occupation_mapping = {
    'Machine-op-inspct': 'Machine Operator',
    'Farming-fishing': 'Farming and Fishing',
    'Protective-serv': 'Protective Services'
}

""" 
    Replaces keywords in the dictionary with value,
    fillna brings back values that were not changed.
"""

df['occupation'].map(occupation_mapping).fillna(df['occupation'])
# Out:
# 0           Machine Operator
# 1        Farming and Fishing
# 2        Protective Services
# 3           Machine Operator
# 5              Other-service
#                 ...
# 48837           Tech-support
# 48838       Machine Operator
# 48839           Adm-clerical
# 48840           Adm-clerical
# 48841        Exec-managerial
# Name: occupation, Length: 45232, dtype: object

# %%
# Replacing parts of strings

# replace(character/value to replace, what to replace it with, regex)
df['occupation'].replace('-', ' ', regex=True)
# Out:
# 0        Machine op inspct
# 1          Farming fishing
# 2          Protective serv
# 3        Machine op inspct
# 5            Other service
#                ...
# 48837         Tech support
# 48838    Machine op inspct
# 48839         Adm clerical
# 48840         Adm clerical
# 48841      Exec managerial
# Name: occupation, Length: 45232, dtype: object

# %%
# Replace parts of integers
df['educational-num'].replace(7, 70, regex=True)
# Out:
# 0        70
# 1         9
# 2        12
# 3        10
# 5         6
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: educational-num, Length: 45232, dtype: int64

# %%
# Changing Column Data Types
df['income'] = df['income'].astype('category')
df['fnlwgt'] = df['fnlwgt'].astype('string')
df.dtypes
# Out:
# age                         int64
# workclass                  object
# fnlwgt             string[python]
# education                  object
# educational-num             int64
# marital-status             object
# occupation                 object
# relationship               object
# race                       object
# gender                     object
# capital-gain                int64
# capital-loss                int64
# hours-per-week              int64
# native-country             object
# income                   category
# dtype: object

# %% [markdown]
# ## **Renaming columns and Reindexing**

# %%
# Change column names

# rename(columns={}, inplace=True)
df.rename(columns={'native-country': 'Country', 'hours-per-week': 'Working Hours'}, inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  Working Hours        Country income
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45232 rows x 15 columns]

# %%
# Reindexing - Only focusing on certain columns
df.reindex(columns=['age', 'gender', 'Country', 'income', 'occupation'])
# Out:
#        age  gender        Country income         occupation
# 0       25    Male  United-States  <=50K  Machine-op-inspct
# 1       38    Male  United-States  <=50K    Farming-fishing
# 2       28    Male  United-States   >50K    Protective-serv
# 3       44    Male  United-States   >50K  Machine-op-inspct
# 5       34    Male  United-States  <=50K      Other-service
# ...    ...     ...            ...    ...                ...
# 48837   27  Female  United-States  <=50K       Tech-support
# 48838   40    Male  United-States   >50K  Machine-op-inspct
# 48839   58  Female  United-States  <=50K       Adm-clerical
# 48840   22    Male  United-States  <=50K       Adm-clerical
# 48841   52  Female  United-States   >50K    Exec-managerial
#
# [45232 rows x 5 columns]

# %% [markdown]
# ### **Filtering and Selecting Data**
#
# Filtering and selecting data are fundamental for focusing analysis on specific segments. Techniques include Boolean indexing for conditional selection, using .query() for complex queries, and filtering data based on conditions.

# %%
# Conditional Filtering / Boolean Indexing
df[df['income'] == '>50K']
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 10      65           Private  184454       HS-grad                9
# 14      48           Private  279724       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 48819   38           Private  139180     Bachelors               13
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48835   53           Private  321865       Masters               14
# 48838   40           Private  154374       HS-grad                9
# 48841   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 7      Married-civ-spouse     Prof-specialty      Husband  White    Male
# 10     Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 14     Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# ...                   ...                ...          ...    ...     ...
# 48819            Divorced     Prof-specialty    Unmarried  Black  Female
# 48826  Married-civ-spouse       Adm-clerical         Wife  White  Female
# 48835  Married-civ-spouse    Exec-managerial      Husband  White    Male
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  Working Hours        Country income
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 7              3103             0             32  United-States   >50K
# 10             6418             0             40  United-States   >50K
# 14             3103             0             48  United-States   >50K
# ...             ...           ...            ...            ...    ...
# 48819         15020             0             45  United-States   >50K
# 48826             0             0             20  United-States   >50K
# 48835             0             0             40  United-States   >50K
# 48838             0             0             40  United-States   >50K
# 48841         15024             0             40  United-States   >50K
#
# [11208 rows x 15 columns]

# %%
# Using .query() for indexing/filtering

""" 
    Columns are put in backticks (`), and can be used for complex
    querying.
"""

high_income = df.query('`income` == ">50K"')
high_income
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 10      65           Private  184454       HS-grad                9
# 14      48           Private  279724       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 48819   38           Private  139180     Bachelors               13
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48835   53           Private  321865       Masters               14
# 48838   40           Private  154374       HS-grad                9
# 48841   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 7      Married-civ-spouse     Prof-specialty      Husband  White    Male
# 10     Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 14     Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# ...                   ...                ...          ...    ...     ...
# 48819            Divorced     Prof-specialty    Unmarried  Black  Female
# 48826  Married-civ-spouse       Adm-clerical         Wife  White  Female
# 48835  Married-civ-spouse    Exec-managerial      Husband  White    Male
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  Working Hours        Country income
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 7              3103             0             32  United-States   >50K
# 10             6418             0             40  United-States   >50K
# 14             3103             0             48  United-States   >50K
# ...             ...           ...            ...            ...    ...
# 48819         15020             0             45  United-States   >50K
# 48826             0             0             20  United-States   >50K
# 48835             0             0             40  United-States   >50K
# 48838             0             0             40  United-States   >50K
# 48841         15024             0             40  United-States   >50K
#
# [11208 rows x 15 columns]

# %%
# Logical/Compound Queries
df.query("`relationship` == 'Wife' and `educational-num` == 13")
# Out:
#        age         workclass  fnlwgt  education  educational-num  \
# 208     34           Private  357145  Bachelors               13
# 376     28           Private  302903  Bachelors               13
# 409     38           Private  272476  Bachelors               13
# 480     39           Private   85783  Bachelors               13
# 581     37  Self-emp-not-inc  143774  Bachelors               13
# ...    ...               ...     ...        ...              ...
# 48313   40         State-gov   31627  Bachelors               13
# 48345   49           Private   93639  Bachelors               13
# 48533   37  Self-emp-not-inc  103925  Bachelors               13
# 48628   36         State-gov  212143  Bachelors               13
# 48709   39       Federal-gov  110622  Bachelors               13
#
#            marital-status       occupation relationship                race  \
# 208    Married-civ-spouse   Prof-specialty         Wife               White
# 376    Married-civ-spouse   Prof-specialty         Wife  Asian-Pac-Islander
# 409    Married-civ-spouse   Prof-specialty         Wife               White
# 480    Married-civ-spouse     Adm-clerical         Wife               White
# 581    Married-civ-spouse   Prof-specialty         Wife               White
# ...                   ...              ...          ...                 ...
# 48313  Married-civ-spouse  Exec-managerial         Wife               White
# 48345  Married-civ-spouse  Exec-managerial         Wife               White
# 48533  Married-civ-spouse            Sales         Wife               White
# 48628  Married-civ-spouse     Adm-clerical         Wife               White
# 48709  Married-civ-spouse     Adm-clerical         Wife  Asian-Pac-Islander
#
#        gender  capital-gain  capital-loss  Working Hours        Country income
# 208    Female             0             0             50  United-States   >50K
# 376    Female             0          1485             40  United-States  <=50K
# 409    Female             0             0             24  United-States   >50K
# 480    Female             0             0             28  United-States  <=50K
# 581    Female             0             0             40        Germany   >50K
# ...       ...           ...           ...            ...            ...    ...
# 48313  Female             0             0             20  United-States  <=50K
# 48345  Female             0             0             43  United-States  <=50K
# 48533  Female             0             0             50  United-States  <=50K
# 48628  Female             0             0             20  United-States   >50K
# 48709  Female             0             0             40    Philippines  <=50K
#
# [417 rows x 15 columns]

# %%
# Getting the unique values of a certain column
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv',
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces',
#        'Unemployed'], dtype=object)

# %% [markdown]
# **Example**
#
# 1. Select individuals working more than 40 hours per week but earning '<=50K'.
# 2. Use .query() to find divorced individuals in the Private sector.

# %%
# Question 1
working_individuals = df.query('`Working Hours` > 40 and `income` == "<=50K"')
working_individuals
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 1       38           Private   89814       HS-grad                9
# 23      25           Private  220931     Bachelors               13
# 27      23           Private  134446       HS-grad                9
# 29      32  Self-emp-not-inc  109282  Some-college               10
# 31      56  Self-emp-not-inc  186651          11th                7
# ...    ...               ...     ...           ...              ...
# 48818   30           Private  345898       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48833   43           Private   84661     Assoc-voc               11
#
#            marital-status         occupation   relationship   race  gender  \
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 23          Never-married     Prof-specialty  Not-in-family  White    Male
# 27              Separated  Machine-op-inspct      Unmarried  Black    Male
# 29          Never-married     Prof-specialty  Not-in-family  White    Male
# 31                Widowed      Other-service      Unmarried  White  Female
# ...                   ...                ...            ...    ...     ...
# 48818       Never-married       Craft-repair  Not-in-family  Black    Male
# 48824            Divorced     Prof-specialty      Unmarried  White  Female
# 48829       Never-married     Prof-specialty  Not-in-family  White    Male
# 48831  Married-civ-spouse       Craft-repair        Husband  White    Male
# 48833  Married-civ-spouse              Sales        Husband  White    Male
#
#        capital-gain  capital-loss  Working Hours        Country income
# 1                 0             0             50  United-States  <=50K
# 23                0             0             43           Peru  <=50K
# 27                0             0             54  United-States  <=50K
# 29                0             0             60  United-States  <=50K
# 31                0             0             50  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48818             0             0             46  United-States  <=50K
# 48824             0             0             48  United-States  <=50K
# 48829          1086             0             60  United-States  <=50K
# 48831             0             0             50  United-States  <=50K
# 48833             0             0             45  United-States  <=50K
#
# [8208 rows x 15 columns]

# %%
# Question 2
priv_divorced = df.query('`marital-status` == "Divorced" and `workclass` == "Private"')
priv_divorced
# Out:
#        age workclass  fnlwgt     education  educational-num marital-status  \
# 34      26   Private   43311       HS-grad                9       Divorced
# 51      39   Private  280215       HS-grad                9       Divorced
# 61      39   Private  118429  Some-college               10       Divorced
# 119     43   Private  179866     Bachelors               13       Divorced
# 123     41   Private  110732  Some-college               10       Divorced
# ...    ...       ...     ...           ...              ...            ...
# 48804   30   Private   77266       HS-grad                9       Divorced
# 48815   37   Private  179137  Some-college               10       Divorced
# 48819   38   Private  139180     Bachelors               13       Divorced
# 48825   31   Private  199655       Masters               14       Divorced
# 48827   37   Private  198216    Assoc-acdm               12       Divorced
#
#               occupation   relationship   race  gender  capital-gain  \
# 34       Exec-managerial      Unmarried  White  Female             0
# 51     Handlers-cleaners      Own-child  Black    Male             0
# 61                 Sales  Not-in-family  White    Male             0
# 119                Sales      Unmarried  White  Female             0
# 123         Tech-support  Not-in-family  White  Female             0
# ...                  ...            ...    ...     ...           ...
# 48804   Transport-moving  Not-in-family  White    Male             0
# 48815       Adm-clerical      Unmarried  White  Female             0
# 48819     Prof-specialty      Unmarried  Black  Female         15020
# 48825      Other-service  Not-in-family  Other  Female             0
# 48827       Tech-support  Not-in-family  White  Female             0
#
#        capital-loss  Working Hours        Country income
# 34                0             40  United-States  <=50K
# 51                0             40  United-States  <=50K
# 61                0             40  United-States  <=50K
# 119               0             40  United-States   >50K
# 123               0             40  United-States  <=50K
# ...             ...            ...            ...    ...
# 48804             0             55  United-States  <=50K
# 48815             0             39  United-States  <=50K
# 48819             0             45  United-States   >50K
# 48825             0             30  United-States  <=50K
# 48827             0             40  United-States  <=50K
#
# [4660 rows x 15 columns]

# %% [markdown]
# ### Removing Columns and Rows

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  Working Hours        Country income
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45232 rows x 15 columns]

# %%
# Drop

# Row (Single)
shortened_df = df.drop(0)

# Row (Multiple)
shortened_df = df.drop([0,1,2])

# Column (Single) [axis=1 means column]
shortened_df = df.drop("fnlwgt", axis=1)

# Column (Multiple) [axis=1 means column]
shortened_df = df.drop(["education", "capital-gain", "capital-loss"], axis=1)
shortened_df
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 5       34       Private  198693                6       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation   relationship   race  gender  Working Hours  \
# 0      Machine-op-inspct      Own-child  Black    Male             40
# 1        Farming-fishing        Husband  White    Male             50
# 2        Protective-serv        Husband  White    Male             40
# 3      Machine-op-inspct        Husband  Black    Male             40
# 5          Other-service  Not-in-family  White    Male             30
# ...                  ...            ...    ...     ...            ...
# 48837       Tech-support           Wife  White  Female             38
# 48838  Machine-op-inspct        Husband  White    Male             40
# 48839       Adm-clerical      Unmarried  White  Female             40
# 48840       Adm-clerical      Own-child  White    Male             20
# 48841    Exec-managerial           Wife  White  Female             40
#
#              Country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States   >50K
# 3      United-States   >50K
# 5      United-States  <=50K
# ...              ...    ...
# 48837  United-States  <=50K
# 48838  United-States   >50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K
#
# [45232 rows x 12 columns]

# %% [markdown]
# ## **Handling Duplicates**
#
# Identifying and removing duplicate records are crucial for maintaining data quality. Pandas provides .duplicated() and .drop_duplicates() for finding and removing duplicates, ensuring each data point is unique for accurate analysis.

# %%
# Checking for duplicates
df.duplicated().sum()
# Out:
# 47

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  Working Hours        Country income
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45185 rows x 15 columns]

# %% [markdown]
# ### **Aggregating Data** (.groupby)
#
# Aggregating data involves summarizing data points into meaningful statistics, such as averages, sums, or counts, which can be achieved using GroupBy operations or pivot tables. This helps in understanding the dataset at a higher level.

# %% [markdown]
# **GroupBy operation: Average age by occupation**

# %%
# Changing data type to category
df['occupation'] = df['occupation'].astype('category')

# Getting unique values for occupation
df['occupation'].unique()
# Out:
# ['Machine-op-inspct', 'Farming-fishing', 'Protective-serv', 'Other-service', 'Prof-specialty', ..., 'Priv-house-serv', 'Transport-moving', 'Handlers-cleaners', 'Armed-Forces', 'Unemployed']
# Length: 15
# Categories (15, object): ['Adm-clerical', 'Armed-Forces', 'Craft-repair', 'Exec-managerial', ..., 'Sales', 'Tech-support', 'Transport-moving', 'Unemployed']

# %%
# Getting the average age per occupation
age_col = df.groupby('occupation')['age'].mean()
age_col
# Out:
# C:\Users\Lettush\AppData\Local\Temp\ipykernel_20348\569039778.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_col = df.groupby('occupation')['age'].mean()
# occupation
# Adm-clerical         37.218609
# Armed-Forces         31.785714
# Craft-repair         38.970882
# Exec-managerial      42.211371
# Farming-fishing      41.400000
# Handlers-cleaners    32.606846
# Machine-op-inspct    37.711298
# Other-service        35.051613
# Priv-house-serv      43.682609
# Prof-specialty       40.531578
# Protective-serv      38.890256
# Sales                37.446253
# Tech-support         37.208598
# Transport-moving     40.721934
# Unemployed           19.900000
# Name: age, dtype: float64

# %% [markdown]
# **Pivot table: Average hours per week by income and gender**

# %%
"""
    pivot_table creates a new table based on:
    - values (columns to be given a function)
    - index (row basis)
    - columns (column basis)
    - aggfunc (what function will be applied to values [i.e. mean, sum])
"""

df.pivot_table(values='Working Hours', index='gender', columns='income', aggfunc='mean', observed=True)
df.pivot_table(values=['Working Hours', 'age'], index='gender', columns='income', aggfunc='mean', observed=True)
# Out:
#        Working Hours                   age
# income         <=50K       >50K      <=50K       >50K
# gender
# Female     36.393730  41.156980  36.345858  42.036549
# Male       41.222424  46.486416  37.007249  44.351726

# %% [markdown]
# ### **Merging and Joining Data**
#
# Merging and joining data with pandas involves combining different datasets based on common columns or indices, enabling a comprehensive analysis of related information spread across multiple sources. pandas supports various types of joins: left, right, inner, and outer, mimicking SQL join operations and providing flexibility in how datasets are combined.
#
# **Types of Joins**
# - Left Join (left): Includes all records from the left DataFrame and matched records from the right DataFrame. Unmatched records in the right DataFrame are not included.
# - Right Join (right): Includes all records from the right DataFrame and matched records from the left DataFrame. Unmatched records in the left DataFrame are not included.
# - Inner Join (inner): Only includes records with matching values in both DataFrames, excluding all unmatched records.
# - Outer Join (outer): Includes all records from both DataFrames, with unmatched records filled with NaN.

# %%
df_employment = pd.DataFrame({
    'occupation': ['Adm-clerical', 'Exec-managerial'],
    'sector': ['Administrative', 'Executive']
})

df_employment
# Out:
#         occupation          sector
# 0     Adm-clerical  Administrative
# 1  Exec-managerial       Executive

# %%
# Inner Join
# Only includes records with matching values in both DataFrames

df_merged = df.merge(df_employment, on="occupation", how="inner")
df_merged
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       36   Federal-gov  212465     Bachelors               13
# 1       26       Private   82091       HS-grad                9
# 2       43       Private  346189       Masters               14
# 3       43       Private  128354       HS-grad                9
# 4       22       Private  236427       HS-grad                9
# ...    ...           ...     ...           ...              ...
# 11510   43     State-gov  255835  Some-college               10
# 11511   53       Private  321865       Masters               14
# 11512   58       Private  151910       HS-grad                9
# 11513   22       Private  201490       HS-grad                9
# 11514   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status       occupation    relationship   race  gender  \
# 0      Married-civ-spouse     Adm-clerical         Husband  White    Male
# 1           Never-married     Adm-clerical   Not-in-family  White  Female
# 2      Married-civ-spouse  Exec-managerial         Husband  White    Male
# 3      Married-civ-spouse     Adm-clerical            Wife  White  Female
# 4           Never-married     Adm-clerical       Own-child  White    Male
# ...                   ...              ...             ...    ...     ...
# 11510            Divorced     Adm-clerical  Other-relative  White  Female
# 11511  Married-civ-spouse  Exec-managerial         Husband  White    Male
# 11512             Widowed     Adm-clerical       Unmarried  White  Female
# 11513       Never-married     Adm-clerical       Own-child  White    Male
# 11514  Married-civ-spouse  Exec-managerial            Wife  White  Female
#
#        capital-gain  capital-loss  Working Hours        Country income  \
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             39  United-States  <=50K
# 2                 0             0             50  United-States   >50K
# 3                 0             0             30  United-States  <=50K
# 4                 0             0             20  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 11510             0             0             40  United-States  <=50K
# 11511             0             0             40  United-States   >50K
# 11512             0             0             40  United-States  <=50K
# 11513             0             0             20  United-States  <=50K
# 11514         15024             0             40  United-States   >50K
#
#                sector
# 0      Administrative
# 1      Administrative
# 2           Executive
# 3      Administrative
# 4      Administrative
# ...               ...
# 11510  Administrative
# 11511       Executive
# 11512  Administrative
# 11513  Administrative
# 11514       Executive
#
# [11515 rows x 16 columns]

# %%
# Outer Join / Full Join
# Includes all records from Both DFs, with unmatched records filled with NaN/null

df_merged = df.merge(df_employment, on="occupation", how="outer")
df_merged
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       36   Federal-gov  212465     Bachelors               13
# 1       26       Private   82091       HS-grad                9
# 2       43       Private  128354       HS-grad                9
# 3       22       Private  236427       HS-grad                9
# 4       21       Private  110677  Some-college               10
# ...    ...           ...     ...           ...              ...
# 45180   17  Never-worked  237272          10th                6
# 45181   18  Never-worked  157131          11th                7
# 45182   20  Never-worked  462294  Some-college               10
# 45183   30  Never-worked  176673       HS-grad                9
# 45184   18  Never-worked  153663  Some-college               10
#
#            marital-status    occupation   relationship   race  gender  \
# 0      Married-civ-spouse  Adm-clerical        Husband  White    Male
# 1           Never-married  Adm-clerical  Not-in-family  White  Female
# 2      Married-civ-spouse  Adm-clerical           Wife  White  Female
# 3           Never-married  Adm-clerical      Own-child  White    Male
# 4           Never-married  Adm-clerical      Own-child  White  Female
# ...                   ...           ...            ...    ...     ...
# 45180       Never-married    Unemployed      Own-child  White    Male
# 45181       Never-married    Unemployed      Own-child  White  Female
# 45182       Never-married    Unemployed      Own-child  Black    Male
# 45183  Married-civ-spouse    Unemployed           Wife  Black  Female
# 45184       Never-married    Unemployed      Own-child  White    Male
#
#        capital-gain  capital-loss  Working Hours        Country income  \
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             39  United-States  <=50K
# 2                 0             0             30  United-States  <=50K
# 3                 0             0             20  United-States  <=50K
# 4                 0             0             40  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 45180             0             0             30  United-States  <=50K
# 45181             0             0             10  United-States  <=50K
# 45182             0             0             40  United-States  <=50K
# 45183             0             0             40  United-States  <=50K
# 45184             0             0              4  United-States  <=50K
#
#                sector
# 0      Administrative
# 1      Administrative
# 2      Administrative
# 3      Administrative
# 4      Administrative
# ...               ...
# 45180             NaN
# 45181             NaN
# 45182             NaN
# 45183             NaN
# 45184             NaN
#
# [45185 rows x 16 columns]

# %%
# Left Join
# Includes all records from the left DataFrame and only matched records from the right DataFrame.
df_merged = df.merge(df_employment, on="occupation", how="left")
df_merged

# Right Join
# Includes all records from the right DataFrame and only matched records from the left DataFrame.
df_merged = df.merge(df_employment, on="occupation", how="right")
df_merged
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       36   Federal-gov  212465     Bachelors               13
# 1       26       Private   82091       HS-grad                9
# 2       43       Private  128354       HS-grad                9
# 3       22       Private  236427       HS-grad                9
# 4       21       Private  110677  Some-college               10
# ...    ...           ...     ...           ...              ...
# 11510   46       Private  364548  Some-college               10
# 11511   54       Private  337992     Bachelors               13
# 11512   34       Private  160216     Bachelors               13
# 11513   53       Private  321865       Masters               14
# 11514   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status       occupation   relationship                race  \
# 0      Married-civ-spouse     Adm-clerical        Husband               White
# 1           Never-married     Adm-clerical  Not-in-family               White
# 2      Married-civ-spouse     Adm-clerical           Wife               White
# 3           Never-married     Adm-clerical      Own-child               White
# 4           Never-married     Adm-clerical      Own-child               White
# ...                   ...              ...            ...                 ...
# 11510  Married-civ-spouse  Exec-managerial        Husband               White
# 11511  Married-civ-spouse  Exec-managerial        Husband  Asian-Pac-Islander
# 11512       Never-married  Exec-managerial  Not-in-family               White
# 11513  Married-civ-spouse  Exec-managerial        Husband               White
# 11514  Married-civ-spouse  Exec-managerial           Wife               White
#
#        gender  capital-gain  capital-loss  Working Hours        Country  \
# 0        Male             0             0             40  United-States
# 1      Female             0             0             39  United-States
# 2      Female             0             0             30  United-States
# 3        Male             0             0             20  United-States
# 4      Female             0             0             40  United-States
# ...       ...           ...           ...            ...            ...
# 11510    Male             0             0             48  United-States
# 11511    Male             0             0             50          Japan
# 11512  Female             0             0             55  United-States
# 11513    Male             0             0             40  United-States
# 11514  Female         15024             0             40  United-States
#
#       income          sector
# 0      <=50K  Administrative
# 1      <=50K  Administrative
# 2      <=50K  Administrative
# 3      <=50K  Administrative
# 4      <=50K  Administrative
# ...      ...             ...
# 11510   >50K       Executive
# 11511   >50K       Executive
# 11512   >50K       Executive
# 11513   >50K       Executive
# 11514   >50K       Executive
#
# [11515 rows x 16 columns]
