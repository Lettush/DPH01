# %% [markdown]
# # PRACTICE EXERCISE
# ---
#
# **Database Setup and Data Insertion**
# 1. Create a table named `Orders`.
# 2. Add the appropriate columns:
#   * **OrderID**: Primary key to uniquely identify each order.
#   * **Quantity**: Number of items ordered.
#   * **Product_Name**: Name of the product ordered.
#   * **Price**: Price per unit of the product.
#   * **Order_Date**: Date when the order was placed.
#   * **Ship_Date**: Date when the order was shipped.
#   * **Product_Type**: Type or category of the product.
#   * **Discount**: Discount applied to the order, if any.
#   * **Total_Amount**: Total amount of the order after applying discounts.
# 3. Insert the provided data below into the Orders table using the INSERT INTO statement.
#
# ![Screenshot 2024-04-29 at 4.24.06 AM.png](data:image/png;base64,...)
#
#
# 4. After executing the needed SQL statements, verify that the Orders table has been created successfully and populated with the provided data.
#
# **Practicing SQL Queries**
# *  Write a query to group the orders by Product_Type and calculates the total sales amount for each product type.
# * List the product names and total amounts of orders, sorted by total amount in descending order.
# * Calculate the average price of products for each product type, sorted by product type alphabetically.
# * List the product names, quantities, and total amounts of orders, where the total amount is greater than $5.00, sorted by total amount in descending order.
# * Count the number of orders for each product type, sorted by the number of orders in descending order.
# * Group the orders by Order_Date and calculates the average discount applied for each order date.
# * Create a query that groups the data by Product_Name and finds the maximum Discount applied for each product.
# * Create a query that filters orders where the Quantity is "2" and orders the results by Product Name in descending order
# * Retrieve the OrderID, Product_Name, and Total_Amount of orders where the discount is applied, ordered by Total_Amount in descending order.
# * Retrieve the Product_Name and Quantity of products that were ordered on or after '2024-04-07', ordered by Quantity in descending order.
# * Retrieve the Product_Type, MIN(Price), and MAX(Price) of products for each product type.

# %% [markdown]
# # PRACTICE EXERCISE #2 (Advanced / Bonus)
# ---
#
# **Database Setup and Data Insertion**
# 1. Create a new table that can be used to join with the existing **ORDERS** table, name it `Product_Data`.
#   > This table will have information about different products sold, which can be related to the products listed in the ORDERS table.
# 2. Add the appropriate columns:
#   * ProductID
#   * Product_Name
#   * Price
#   * Product_Type
# 3. Insert these data below in the `Product_Data` table:
#
# ![Screenshot 2024-04-29 at 4.31.20 AM.png](data:image/png;base64,...)
#
# 4. After executing the needed SQL statements, verify that the Product_Data table has been created successfully and populated with the provided data.
#
# **Practicing SQL Queries**
# * Calculate the average salary for each department and show departments with an average salary above 55,000
# * Create a query that will return the number of Orders Placed for Each Product
# * Create a query that will join the Orders table with the Product_Data table based on the Product_Name column, and it will retrieve data from both tables, showing the product types instead of product names in the ORDERS table.
# * Calculate the average total amount for each product type and then filters out only those product types where the average total amount is greater than 5. You will use Inner Join, Group By and Having.
# * Retrieve a list of orders along with their product details using Inner Join
# * Retrieve all products along with the number of orders made for each product, including products that have not been ordered, using Left Join.
# * Retrieve all orders along with their product details, including products that do not have any orders, using Right Join
# * Retrieve a Cartesian product of all rows from both tables, using Cross Join
